# %%
import numpy as np
import pandas as pd
r_no = 102317248
np.random.seed(r_no)

sales_data = np.random.randint(1000, 5001, size=(12, 4))

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
columns = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]

sales = pd.DataFrame(sales_data, index=months, columns=columns)

print(sales)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         2808      1907            1443    2140
# Feb         3038      1649            1614    4123
# Mar         2078      1626            1592    3139
# Apr         3915      3866            4830    4747
# May         3495      1988            4076    4556
# Jun         3388      4919            3893    1770
# Jul         2069      1048            1275    2725
# Aug         3339      4676            3110    2369
# Sep         4393      4717            3382    3065
# Oct         4891      1792            2632    4550
# Nov         3181      4426            1716    1152
# Dec         3347      4348            1659    4044

# %%
print(sales.head())
print(sales.describe())

total_sales_per_category = sales.sum()
print()
print(total_sales_per_category)

total_sales_per_month = sales.sum(axis=1)
print()
print(total_sales_per_month)

average_growth = sales.pct_change().mean()
print()
print(average_growth)

sales["Total Sales"] = total_sales_per_month
sales["Growth Rate"] = sales["Total Sales"].pct_change() * 100

if(r_no%2==0):
  sales["Electronics"] *= 0.9
else:
  sales["Electronics"] *= 0.85

print(sales)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         2808      1907            1443    2140
# Feb         3038      1649            1614    4123
# Mar         2078      1626            1592    3139
# Apr         3915      3866            4830    4747
# May         3495      1988            4076    4556
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3328.500000  3080.166667     2601.833333  3198.333333
# std     824.478954  1512.507841     1222.716932  1203.011852
# min    2069.000000  1048.000000     1275.000000  1152.000000
# 25%    2980.500000  1756.250000     1608.500000  2311.750000
# 50%    3343.000000  2927.000000     2174.000000  3102.000000
# 75%    3600.000000  4488.500000     3509.750000  4229.750000
# max    4891.000000  4919.000000     4830.000000  4747.000000
#
# Electronics       39942
# Clothing          36962
# Home & Kitchen    31222
# Sports            38380
# dtype: int64
#
# Jan     8298
# Feb    10424
# Mar     8435
# Apr    17358
# May    14115
# Jun    13970
# Jul     7117
# Aug    13494
# Sep    15557
# Oct    13865
# Nov    10475
# Dec    13398
# dtype: int64
#
# Electronics       0.078921
# Clothing          0.521159
# Home & Kitchen    0.198997
# Sports            0.318119
# dtype: float64
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       2527.2      1907            1443    2140         8298          NaN
# Feb       2734.2      1649            1614    4123        10424    25.620631
# Mar       1870.2      1626            1592    3139         8435   -19.080967
# Apr       3523.5      3866            4830    4747        17358   105.785418
# May       3145.5      1988            4076    4556        14115   -18.683028
# Jun       3049.2      4919            3893    1770        13970    -1.027276
# Jul       1862.1      1048            1275    2725         7117   -49.055118
# Aug       3005.1      4676            3110    2369        13494    89.602361
# Sep       3953.7      4717            3382    3065        15557    15.288276
# Oct       4401.9      1792            2632    4550        13865   -10.876133
# Nov       2862.9      4426            1716    1152        10475   -24.450054
# Dec       3012.3      4348            1659    4044        13398    27.904535

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=sales[columns], markers=True)
plt.title("Monthly Sales Trends for Each Category")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend(columns)
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(data=sales[columns])
plt.title("Sales Distribution for Each Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
array = np.array([[1, -2, 3], [-4, 5, -6]])

absolute_array = np.abs(array)
print("Absolute Array:\n", absolute_array)

flattened_percentiles = np.percentile(array, [25, 50, 75])
column_percentiles = np.percentile(array, [25, 50, 75], axis=0)
row_percentiles = np.percentile(array, [25, 50, 75], axis=1)
print("Flattened Percentiles:", flattened_percentiles)
print("Column Percentiles:\n", column_percentiles)
print("Row Percentiles:\n", row_percentiles)

flattened_mean = np.mean(array)
flattened_median = np.median(array)
flattened_std = np.std(array)
print("Flattened Mean:", flattened_mean)
print("Flattened Median:", flattened_median)
print("Flattened Standard Deviation:", flattened_std)

column_mean = np.mean(array, axis=0)
column_median = np.median(array, axis=0)
column_std = np.std(array, axis=0)
print("Column Mean:\n", column_mean)
print("Column Median:\n", column_median)
print("Column Standard Deviation:\n", column_std)

row_mean = np.mean(array, axis=1)
row_median = np.median(array, axis=1)
row_std = np.std(array, axis=1)
print("Row Mean:\n", row_mean)
print("Row Median:\n", row_median)
print("Row Standard Deviation:\n", row_std)
# Out:
# Absolute Array:
#  [[1 2 3]
#  [4 5 6]]
# Flattened Percentiles: [-3.5 -0.5  2.5]
# Column Percentiles:
#  [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# Row Percentiles:
#  [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# Flattened Mean: -0.5
# Flattened Median: -0.5
# Flattened Standard Deviation: 3.8622100754188224
# Column Mean:
#  [-1.5  1.5 -1.5]
# Column Median:
#  [-1.5  1.5 -1.5]
# Column Standard Deviation:
#  [2.5 3.5 4.5]
# Row Mean:
#  [ 0.66666667 -1.66666667]
# Row Median:
#  [ 1. -4.]
# Row Standard Deviation:
#  [2.05480467 4.78423336]

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])

print("Floor Values:", np.floor(a))
print("Ceiling Values:", np.ceil(a))
print("Truncated Values:", np.trunc(a))
print("Rounded Values:", np.round(a))
# Out:
# Floor Values: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling Values: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated Values: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded Values: [-2. -2. -0.  0.  2.  2.  3.]

# %%
def swap(lst, index1, index2):
    temp = lst[index1]
    lst[index1] = lst[index2]
    lst[index2] = temp
    return lst

my_list = [1, 2, 3, 4, 5]
index1, index2 = 2, 3
print("Original List:", my_list)
print("Swapped List:", swap(my_list, index1, index2))
# Out:
# Original List: [1, 2, 3, 4, 5]
# Swapped List: [1, 2, 4, 3, 5]

# %%
def swap(s, elem1, elem2):
    lst = list(s)
    index1, index2 = lst.index(elem1), lst.index(elem2)
    lst[index1], lst[index2] = lst[index2], lst[index1]
    return set(lst)

my_set = {1, 2, 3, 4, 5}
elem1, elem2 = 2, 3
print("Original Set:", my_set)
print("Modified Set:", swap(my_set, elem1, elem2))
# Out:
# Original Set: {1, 2, 3, 4, 5}
# Modified Set: {1, 2, 3, 4, 5}
